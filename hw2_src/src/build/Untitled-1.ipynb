# %% [markdown]
# <strong>EVAL 2
#
# Yunzhe Yu
# <strong>

# %% [markdown]
# <STRONG>EVAL Problem 1
# <Strong>

# %% [markdown]
# a)

# %%
# Import necessary libraries
import numpy as np
import matplotlib.pyplot as plt
import re

# Define the path to the input file
input_file_path = "/Users/hasanmustafabayli/Desktop/output.txt"

# Read the content from the input file
with open(input_file_path, "r") as input_file:
    input_lines = input_file.readlines()

# Extract time intervals from the input data
time_intervals = []
for line in input_lines:
    length_match = re.search(r'Len: (\d+\.\d+)', line)
    if length_match:
        time_intervals.append(float(length_match.group(1)))

# Define bins for the histogram
bin_width = 0.005
histogram_bins = np.arange(0, max(time_intervals) + bin_width, bin_width)

# Calculate histogram counts
histogram_counts, bin_edges = np.histogram(time_intervals, bins=histogram_bins)

# Normalize the histogram counts by the total number of requests
total_requests = len(time_intervals)
normalized_histogram = histogram_counts / total_requests

# Plotting
plt.figure(figsize=(10, 6))
plt.bar(bin_edges[:-1], normalized_histogram, width=bin_width, align='edge', alpha=0.75)
plt.xlabel('Request Length (seconds)')
plt.ylabel('Normalized Frequency')
plt.title('Distribution of Request Lengths')
plt.xticks(np.arange(0, max(bin_edges) + bin_width, 0.05))
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %% [markdown]
# b)

# %%
# Import necessary libraries
import numpy as np
import matplotlib.pyplot as plt
import re

# Read the data from a file
with open( "/Users/hasanmustafabayli/Desktop/output.txt", "r") as data_file:
    lines = data_file.readlines()

# Extract send timestamps from the data
send_times = []
for line in lines:
    pattern_match = re.search(r'Send Time: (\d+\.\d+)', line)
    if pattern_match:
        send_times.append(float(pattern_match.group(1)))

# Calculate inter-arrival intervals
aintervals = [send_times[i+1] - send_times[i] for i in range(len(send_times)-1)]

# Define bins for the histogram
hist_bins = np.arange(0, max(aintervals) + 0.005, 0.005)

# Create histogram data
hist_data, bin_edges = np.histogram(aintervals, bins=hist_bins)

# Normalize the histogram data by the total number of inter-arrival intervals
total_samples = len(aintervals)
normalized_hist_data = hist_data / total_samples

# Adjust the x-axis tick marks to reduce overlap
x_tick_interval = 0.1 if max(bin_edges) < 5 else 0.5

# Plot the histogram with adjusted tick marks
plt.figure(figsize=(12,6))
plt.bar(bin_edges[:-1], normalized_hist_data, width=0.005, align='edge', alpha=0.75)
plt.xlabel('Inter-arrival Time (seconds)')
plt.ylabel('Normalized Frequency')
plt.title('Distribution of Inter-arrival Times')
plt.xticks(np.arange(0, max(bin_edges)+x_tick_interval, x_tick_interval))
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %% [markdown]
# c)

# %%
import numpy as np
import matplotlib.pyplot as plt

# Number of samples
num_samples = 10000

# Generate samples for the theoretical distributions
normal_samples = np.random.normal(loc=1/10, scale=1, size=num_samples)
exponential_samples = np.random.exponential(scale=1/10, size=num_samples)
uniform_samples = np.random.uniform(low=0, high=1/5, size=num_samples)  # To get a mean of 1/10, the range is [0, 1/5]

# Define bins for the histogram (based on the previous experimental data)
bins = np.arange(0, max(request_lengths) + 0.005, 0.005)

# Histogram data for the theoretical distributions
hist_normal, bin_edges_normal = np.histogram(normal_samples, bins=bins, density=True)
hist_exponential, bin_edges_exponential = np.histogram(exponential_samples, bins=bins, density=True)
hist_uniform, bin_edges_uniform = np.histogram(uniform_samples, bins=bins, density=True)

# Histogram data for the experimental distribution (request lengths)
hist_experiment, bin_edges_experiment = np.histogram(request_lengths, bins=bins, density=True)

# Plotting
plt.figure(figsize=(12,8))
plt.plot(bin_edges_normal[:-1], hist_normal, label='Normal Distribution', alpha=0.75)
plt.plot(bin_edges_exponential[:-1], hist_exponential, label='Exponential Distribution', alpha=0.75)
plt.plot(bin_edges_uniform[:-1], hist_uniform, label='Uniform Distribution', alpha=0.75)
plt.plot(bin_edges_experiment[:-1], hist_experiment, label='Experimental Data', linestyle='--', color='black', alpha=0.75)
plt.xlabel('Value')
plt.ylabel('Density')
plt.title('Comparison of Theoretical Distributions with Experimental Data')
plt.legend()
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %% [markdown]
# d)

# %%
import numpy as np
import matplotlib.pyplot as plt

# Number of samples
num_samples = 10000

# Generate samples for the theoretical distributions with new parameters
normal_samples_interarrival = np.random.normal(loc=1/6, scale=1, size=num_samples)
exponential_samples_interarrival = np.random.exponential(scale=1/6, size=num_samples)
uniform_samples_interarrival = np.random.uniform(low=0, high=1/3, size=num_samples)  # To get a mean of 1/6, the range is [0, 1/3]

# Define bins for the histogram (based on the previous experimental data for inter-arrival times)
bins_interarrival = np.arange(0, max(inter_arrival_times) + 0.005, 0.005)

# Histogram data for the theoretical distributions
hist_normal_interarrival, bin_edges_normal_interarrival = np.histogram(normal_samples_interarrival, bins=bins_interarrival, density=True)
hist_exponential_interarrival, bin_edges_exponential_interarrival = np.histogram(exponential_samples_interarrival, bins=bins_interarrival, density=True)
hist_uniform_interarrival, bin_edges_uniform_interarrival = np.histogram(uniform_samples_interarrival, bins=bins_interarrival, density=True)

# Histogram data for the experimental inter-arrival times
hist_experiment_interarrival, bin_edges_experiment_interarrival = np.histogram(inter_arrival_times, bins=bins_interarrival, density=True)

# Plotting
plt.figure(figsize=(12,8))
plt.plot(bin_edges_normal_interarrival[:-1], hist_normal_interarrival, label='Normal Distribution', alpha=0.75)
plt.plot(bin_edges_exponential_interarrival[:-1], hist_exponential_interarrival, label='Exponential Distribution', alpha=0.75)
plt.plot(bin_edges_uniform_interarrival[:-1], hist_uniform_interarrival, label='Uniform Distribution', alpha=0.75)
plt.plot(bin_edges_experiment_interarrival[:-1], hist_experiment_interarrival, label='Experimental Data (Inter-arrival)', linestyle='--', color='black', alpha=0.75)
plt.xlabel('Inter-arrival Time (seconds)')
plt.ylabel('Density')
plt.title('Comparison of Theoretical Distributions with Experimental Inter-arrival Times')
plt.legend()
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %% [markdown]
# Insights on -a and -s parameters:
#
# Given the observations:
#
# The -a parameter likely controls the average inter-arrival time or request length. Since the exponential distribution fits both request lengths and inter-arrival times well, it suggests that the client might be generating requests or inter-arrival times following a Poisson process, which is characterized by an exponential distribution.
#
# The -s parameter might control the variability or spread of the requests or inter-arrival times. However, without more specific data on how varying -s impacts the distributions, it's a bit more challenging to pin down its exact role.
# The combination of both parameters seems to dictate the overall behavior and pattern of the client's requests to the server.
